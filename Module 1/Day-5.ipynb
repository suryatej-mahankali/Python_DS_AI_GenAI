# %% [markdown]
# Data Structures

# %% [markdown]
# 1.LIST

# %%
fruits = ["apple","banana","cherry","blueberry","orange"] #indexing[0,1,2,3,4],negativeindexing [-5,-4,-3,-2,-1]
         [0          1        2          3          4 ]

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[-1]
# Out:
# 'orange'

# %%
fruits[-3]
# Out:
# 'cherry'

# %%
fruits[2:5]
# Out:
# ['cherry', 'blueberry', 'orange']

# %%
fruits[2:]
# Out:
# ['cherry', 'blueberry', 'orange']

# %%
fruits[1:3]
# Out:
# ['banana', 'cherry']

# %%
fruits[-4:-2]
# Out:
# ['banana', 'cherry']

# %%
fruits[-5:]
# Out:
# ['apple', 'banana', 'cherry', 'blueberry', 'orange']

# %%
fruits[::-1]
# Out:
# ['orange', 'blueberry', 'cherry', 'banana', 'apple']

# %%
fruits[::3]
# Out:
# ['apple', 'blueberry']

# %%
fruits[::-2]
# Out:
# ['orange', 'cherry', 'apple']

# %%
sample= [2,3,4,5,6,6,7,7,8,8,9,99,0,0,0]

# %%
sample[::4] #[0,9,7,4] #[2,6,8,0]
# Out:
# [2, 6, 8, 0]

# %%
sample.append("new value")

# %%
sample
# Out:
# [2, 3, 4, 5, 6, 6, 7, 7, 8, 8, 9, 99, 0, 0, 0, 'new value']

# %%
sample.extend([1000,2000,3000])

# %%
sample
# Out:
# [2, 3, 4, 5, 6, 6, 7, 7, 8, 8, 9, 99, 0, 0, 0, 'new value', 1000, 2000, 3000]

# %%
sample[13]="hello"
sample
# Out:
# [2,
#  3,
#  4,
#  5,
#  6,
#  6,
#  7,
#  7,
#  8,
#  8,
#  9,
#  99,
#  0,
#  'hello',
#  0,
#  'new value',
#  1000,
#  2000,
#  3000]

# %%
sample
# Out:
# [2,
#  3,
#  4,
#  5,
#  6,
#  6,
#  7,
#  7,
#  8,
#  8,
#  9,
#  99,
#  0,
#  'hello',
#  0,
#  'new value',
#  1000,
#  2000,
#  3000]

# %%
sample.insert(0,"Am first")

# %%
sample
# Out:
# ['Am first',
#  2,
#  3,
#  4,
#  5,
#  6,
#  6,
#  7,
#  7,
#  8,
#  8,
#  9,
#  99,
#  0,
#  'hello',
#  0,
#  'new value',
#  1000,
#  2000,
#  3000]

# %%
sample.remove('new value')

# %%
sample
# Out:
# ['Am first',
#  2,
#  3,
#  4,
#  5,
#  6,
#  6,
#  7,
#  7,
#  8,
#  8,
#  9,
#  99,
#  0,
#  'hello',
#  0,
#  1000,
#  2000,
#  3000]

# %%
sample.pop(0)
# Out:
# 'Am first'

# %%
sample
# Out:
# [2, 3, 4, 5, 6, 6, 7, 7, 8, 8, 9, 99, 0, 'hello', 0, 1000, 2000, 3000]

# %%
sample.pop(-5)
# Out:
# 'hello'

# %%
sample
# Out:
# [2, 3, 4, 5, 6, 6, 7, 7, 8, 8, 9, 99, 0, 0, 1000, 2000, 3000]
