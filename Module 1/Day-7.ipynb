# %%
student = {"name":"Surya","age":31,"grade":"A","city":"Hyderabad"}
student
# Out:
# {'name': 'Surya', 'age': 31, 'grade': 'A', 'city': 'Hyderabad'}

# %%
student.get('city')
# Out:
# 'Hyderabad'

# %%
student.get("City",'N/A')
# Out:
# 'N/A'

# %%
student['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 student['Name']
#
# KeyError: 'Name'

# %%
student['name']
# Out:
# 'Surya'

# %%
student['grade']='B'

# %%
student
# Out:
# {'name': 'Surya', 'age': 31, 'grade': 'B', 'city': 'Hyderabad', 'garde': 'B'}

# %%
del student['garde']

# %%
student
# Out:
# {'name': 'Surya', 'age': 31, 'grade': 'B', 'city': 'Hyderabad'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade', 'city'])

# %%
student.values()
# Out:
# dict_values(['Surya', 31, 'B', 'Hyderabad'])

# %%
for key,value in student.items():
    print(f"{key}:{value}")
# Out:
# name:Surya
# age:31
# grade:B
# city:Hyderabad

# %%
squares = {val: val **2 for val in range(1,6)}
squares
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
squares = {val for val in range(1,6)}
squares
# Out:
# {1, 2, 3, 4, 5}

# %%
type(squares)
# Out:
# set

# %%
squares
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
sample = {key:val**2 for key,val in squares.items()}
sample
# Out:
# {1: 1, 2: 16, 3: 81, 4: 256, 5: 625}

# %%
classroom = {"student1":{"name":"surya","grade":"A","city":"hyd"},
             "student2":{"name":"rishi","grade":"A","city":"secbad"}
             }

# %%
classroom
# Out:
# {'student1': {'name': 'surya', 'grade': 'A', 'city': 'hyd'},
#  'student2': {'name': 'rishi', 'grade': 'A', 'city': 'secbad'}}

# %%
classroom['student1']['city']
# Out:
# 'hyd'

# %%
classroom['student1']['city'] ='chennai'

# %%
classroom
# Out:
# {'student1': {'name': 'surya', 'grade': 'A', 'city': 'chennai'},
#  'student2': {'name': 'rishi', 'grade': 'A', 'city': 'secbad'}}

# %%
classroom['student1']= {"Name":"Surya",'grade': 'A', 'city': 'chennai'}

# %%
classroom
# Out:
# {'student1': {'Name': 'Surya', 'grade': 'A', 'city': 'chennai'},
#  'student2': {'name': 'rishi', 'grade': 'A', 'city': 'secbad'}}

# %%
classroom['student1']
# Out:
# {'Name': 'Surya', 'grade': 'A', 'city': 'chennai'}

# %%
classroom['student1'].keys()
# Out:
# dict_keys(['Name', 'grade', 'city'])

# %%
classroom['student1'].keys()[0]="dsbd"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 classroom['student1'].keys()[0]="dsbd"
#
# TypeError: 'dict_keys' object does not support item assignment

# %%
from collections import Counter

# %%
text = "abjdsaffkhdagfiuascvxsaeaaaa"
counts = Counter(text)
counts

# %%
counts.most_common(3)
# Out:
# [('a', 9), ('s', 3), ('f', 3)]

# %%
sample = [5,5,5,53,3,3,345,6,6,6,32,22,5,66,77,6,]
Counter(sample)
# Out:
# Counter({5: 4, 6: 4, 3: 2, 53: 1, 345: 1, 32: 1, 22: 1, 66: 1, 77: 1})

# %%
type(squares)
# Out:
# dict

# %%
student.update({"country":"India"})

# %%
student
# Out:
# {'name': 'Surya',
#  'age': 31,
#  'grade': 'B',
#  'city': 'Hyderabad',
#  'country': 'India'}

# %%
student.pop("age")
# Out:
# 31

# %%
student
# Out:
# {'name': 'Surya', 'grade': 'B', 'city': 'Hyderabad', 'country': 'India'}
