# %%
name =123

# %%
type(name)
# Out:
# int

# %%
firstname,last = "Surya",'''tej'''

# %%
print(last)
# Out:
# tej

# %%
firstname
# Out:
# 'Surya'

# %%
name
# Out:
# 123

# %%
id(name)
# Out:
# 140737025553128

# %%
print(f"Name:{name},id:{firstname}")
# Out:
# Name:123,id:Surya

# %%
print("Name",firstname)
# Out:
# Name Surya
