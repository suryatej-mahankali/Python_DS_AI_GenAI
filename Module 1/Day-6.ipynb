# %% [markdown]
# Lists continuation

# %%
scores=[78,45,89,122,44,23,65]
scores.sort()

# %%
scores.sort(reverse=True)

# %%
scores
# Out:
# [122, 89, 78, 65, 45, 44, 23]

# %%
smaple=[78,45,89,122,44,23,65]

# %%
new_sample =sorted(scores)
new_sample
# Out:
# [23, 44, 45, 65, 78, 89, 122]

# %% [markdown]
# List Comprehensions

# %%
for i in new_sample:
    print(i)
# Out:
# 23
# 44
# 45
# 65
# 78
# 89
# 122

# %%
squares = [ i **2 for i in new_sample ]
squares
# Out:
# [529, 1936, 2025, 4225, 6084, 7921, 14884]

# %%
#even number squares in a list

new_sample
# Out:
# [23, 44, 45, 65, 78, 89, 122]

# %%
even_squares =  [i **2 for i in new_sample if i %2 ==0]
even_squares
# Out:
# [1936, 6084, 14884]

# %% [markdown]
# String manipulation with comprehension

# %%
words= ["hello","WORLD","Python"]

lower_words = [word.lower() for word in words]
lower_words
# Out:
# ['hello', 'world', 'python']

# %%
lower_words=[]
for word in words:
    lower_words.append(word.lower())
lower_words
# Out:
# ['hello', 'world', 'python']

# %%
nested_list = [[1,2],[3,4],[5,6],[7,8]]

# %%
nested_list[0][0]=4

# %%
nested_list
# Out:
# [[4, 2], [3, 4], [5, 6], [7, 8]]

# %%
type(nested_list[0][0])
# Out:
# int

# %%
#[4,2,3,4,5,6,7,8]

flat = [v for val in nested_list for v in val] 
flat
# Out:
# [4, 2, 3, 4, 5, 6, 7, 8]

# %%
flat =[]
for val in nested_list:
    print(val)
    for v in val:
        print(v)
        flat.append(v)
flat
# Out:
# [4, 2]
# 4
# 2
# [3, 4]
# 3
# 4
# [5, 6]
# 5
# 6
# [7, 8]
# 7
# 8
# [4, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# Tuples

# %%
points = (3,6)

# %%
type(points)
# Out:
# tuple

# %%
points[0]=4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 points[0]=4
#
# TypeError: 'tuple' object does not support item assignment

# %%
single_tuple=(5,)

# %%
single_tuple
# Out:
# (5,)

# %%
not_tuple=(5)

# %%
type(not_tuple)
# Out:
# int

# %%
points
# Out:
# (3, 6)

# %%
x,y =points
print(x)
print(y)
# Out:
# 3
# 6

# %%
rgb = (255,126,89)

# %%
r,g,b = rgb

# %%
g
# Out:
# 126

# %%
points.index(3)
# Out:
# 0

# %%
sum(points)
# Out:
# 9

# %%
sorted(points)
# Out:
# [3, 6]

# %% [markdown]
# Sets

# %%
nums={1,2,3,4,8,3,5}

# %%
nums
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
sample=[1,2,44,4,8,3,1,5]
res = set(sample)
res
# Out:
# {1, 2, 3, 4, 5, 8, 44}

# %%
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}

# %%
a|b #union
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
a & b #intersection
# Out:
# {4, 5}

# %%
a - b
# Out:
# {1, 2, 3}

# %%
b - a #difference
# Out:
# {6, 7, 8}

# %%
a ^ b #symmetric difference
# Out:
# {1, 2, 3, 6, 7, 8}
