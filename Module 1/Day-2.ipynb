# %% [markdown]
# Type casting

# %%
num =42

# %%
num=str(num)

# %%
num
# Out:
# '42'

# %%
float(num)
# Out:
# 42.0

# %%
isinstance(num,float)
# Out:
# False

# %%
isinstance(num,str)
# Out:
# True

# %%
int("hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 int("hello")
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %% [markdown]
# Operators

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
10 % 3
# Out:
# 1

# %%
2 **5
# Out:
# 32

# %%
2*5
# Out:
# 10

# %%
2**3
# Out:
# 8

# %% [markdown]
# Comparison

# %%
5 == 5
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
5>3 and 10>7
# Out:
# True

# %% [markdown]
# Bitwise Operators

# %%
a = 5 #binary = 0101
b = 3 # binary = 0011
a&b
# Out:
# 1

# %%
a|b   #   0111
# Out:
# 7

# %%
a^b #   0110
# Out:
# 6

# %%
~a
# Out:
# -6

# %%
a<<1 #1010
# Out:
# 10

# %%
a>>1 #0010
# Out:
# 2

# %% [markdown]
# Assignment Operators

# %%
x = 10  
x +=5 # x = x+5

# %%
x
# Out:
# 15

# %%
x -=3
x
# Out:
# 12

# %%
x **=2

# %%
x
# Out:
# 144

# %% [markdown]
# String Methods

# %%
text = " Hello, World, Python "

# %%
text.strip()
# Out:
# 'Hello, World, Python'

# %%
words = text.split(",")
words
# Out:
# ['Hello', ' World', ' Python']

# %%
type(words)
# Out:
# list

# %%
text
# Out:
# 'Hello, World, Python'

# %%
#['Hello', ' World', ' Python']
sample = []
for w in words:
    sample.append(w.strip())

# %%
sample
# Out:
# ['Hello', 'World', 'Python']

# %%
preprocessed  = ",".join(sample)
preprocessed
# Out:
# 'Hello,World,Python'

# %%
preprocessed  = " ".join(sample)
preprocessed
# Out:
# 'Hello World Python'

# %%
preprocessed= preprocessed.replace("World","Surya")

# %%
preprocessed
# Out:
# 'Hello Surya Python'

# %%
preprocessed.find("y")
# Out:
# 9

# %%
low_pre_process = preprocessed.lower()

# %%
preprocessed
# Out:
# 'Hello Surya Python'

# %%
low_pre_process
# Out:
# 'hello surya python'
